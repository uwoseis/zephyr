# %% [markdown]
# # Basic Helmholtz solver

# %% [markdown]
# Brendan Smithyman | September–October 2014

# %% [markdown]
# ## Imports and setup

# %%
import numpy as np
import scipy.sparse as sp
from SimPEG import Utils
from zephyr import *
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/smithyman/local/anaconda/lib/python2.7/site-packages/setuptools-5.8-py2.7.egg/pkg_resources.py:1032: UserWarning: /home/smithyman/.python-eggs is writable by group/others and vulnerable to attack when used with get_resource_filename. Consider a more secure location (set with .set_extraction_path or the PYTHON_EGG_CACHE environment variable).

# %%
import matplotlib
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('png')
matplotlib.rcParams['savefig.dpi'] = 150 # Change this to adjust figure size

# Plotting options
font = {
    'family': 'Bitstream Vera Sans',
    'weight': 'normal',
    'size': 12,
}

matplotlib.rc('font', **font)

# %% [markdown]
# ## Configuration

# %%
cellSize    = 1             # m
freq        = 1e2           # Hz        (should this be multiplied by 2*pi?)
velocity    = 2000          # m/s
density     = 2700             # units of density
Q           = 2e1           # can be inf
nx          = 200           # count
nz          = 200           # count
freeSurf    = [False, False, False, False] # t r b l
dims        = (nx,nz)       # tuple
sLoc        = [ 10,190]     # x, z
c           = np.ones(dims) * velocity
rho         = np.ones(dims) * density
systemConfig = {
    'dx':   cellSize,       # m
    'dz':   cellSize,       # m
    'freq':     freq,       # Hz
    'c':        c,          # m/s
    'rho':      rho,        # density
    'Q':        Q,          # can be inf
    'nx':       nx,         # count
    'nz':       nz,         # count
    'sLoc':     sLoc,       # x, z
    'freeSurf': freeSurf,   # t r b l
}

# %% [markdown]
# ## Mesh + system initialization

# %%
mesh, A = initHelmholtzNinePointCE(systemConfig)
#Solver = SimPEG.SolverWrapI(sp.linalg.bicg)
Solver = SimPEG.SolverWrapD(sp.linalg.splu)
Ainv = Solver(A)

# %% [markdown]
# ## Source initialization

# %%
q       = np.zeros(mesh.nN)
qI      = Utils.closestPoints(mesh, sLoc, gridLoc='N')
q[qI]   = 1

# %% [markdown]
# ## Testing

# %%
# %%time
u       = Ainv * q
# Out:
# CPU times: user 567 ms, sys: 27 ms, total: 594 ms
# Wall time: 41.5 ms

# %%
amax    = abs(u).max()

ax1 = plt.subplot(1,2,1, aspect=1)
plt.set_cmap(cm.gray_r)
im1 = mesh.plotImage(q, vType='N', ax=ax1)
plt.title('Source location')

ax2 = plt.subplot(1,2,2, aspect=1)
plt.set_cmap(cm.bwr)
im2 = mesh.plotImage(u, vType='N', ax=ax2)
im2[0].set_clim(-amax, amax)
plt.title('Wavefield')

# %%
# %%time
sLoc    = [ 10,100] # x, z
q       = np.zeros(mesh.nN)
qI      = Utils.closestPoints(mesh, sLoc, gridLoc='N')
q[qI]   = 1
u       = Ainv * q
# Out:
# CPU times: user 536 ms, sys: 20 ms, total: 556 ms
# Wall time: 37.6 ms

# %%
amax    = abs(u).max()

ax1 = plt.subplot(1,2,1, aspect=1)
plt.set_cmap(cm.gray_r)
im1 = mesh.plotImage(q, vType='N', ax=ax1)
plt.title('Source location')

ax2 = plt.subplot(1,2,2, aspect=1)
plt.set_cmap(cm.bwr)
im2 = mesh.plotImage(u, vType='N', ax=ax2)
im2[0].set_clim(-amax, amax)
plt.title('Wavefield')

# %%
# %%time
sLoc    = [ 100,100] # x, z
q       = np.zeros(mesh.nN)
qI      = Utils.closestPoints(mesh, sLoc, gridLoc='N')
q[qI]   = 1
u       = Ainv * q
# Out:
# CPU times: user 534 ms, sys: 14 ms, total: 548 ms
# Wall time: 37 ms

# %%
amax    = abs(u).max()

ax1 = plt.subplot(1,2,1, aspect=1)
plt.set_cmap(cm.gray_r)
im1 = mesh.plotImage(q, vType='N', ax=ax1)
plt.title('Source location')

ax2 = plt.subplot(1,2,2, aspect=1)
plt.set_cmap(cm.bwr)
im2 = mesh.plotImage(u, vType='N', ax=ax2)
im2[0].set_clim(-amax, amax)
plt.title('Wavefield')
