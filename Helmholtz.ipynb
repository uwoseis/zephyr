# %% [markdown]
# # Basic Helmholtz solver

# %% [markdown]
# Brendan Smithyman | September–October 2014

# %% [markdown]
# ## Imports and setup

# %%
import numpy as np
from SimPEG import Utils
from zephyr import *
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import matplotlib
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('png')
matplotlib.rcParams['savefig.dpi'] = 150 # Change this to adjust figure size

# Plotting options
font = {
    'family': 'Bitstream Vera Sans',
    'weight': 'normal',
    'size': 12,
}

matplotlib.rc('font', **font)

# %% [markdown]
# ## Configuration

# %%
cellSize    = 1             # m
freq        = 5e1           # Hz        (should this be multiplied by 2*pi?)
velocity    = 2000          # m/s
density     = 1             # units of density
Q           = 2e1           # can be inf
nx          = 100           # count
nz          = 200           # count
dims        = (nx,nz)       # tuple
sLoc        = [ 10,190]     # x, z
c           = np.ones(dims) * velocity
rho         = np.ones(dims) * density
systemConfig = {
    'dx':   cellSize,   # m
    'dz':   cellSize,   # m
    'freq':     freq,   # Hz
    'c':        c,      # m/s
    'rho':      rho,    # density
    'Q':        2e1,    # can be inf
    'nx':       100,    # count
    'nz':       200,    # count
    'sLoc': [ 10, 190], # x, z
}

# %% [markdown]
# ## Mesh + system initialization

# %%
mesh, A, Ainv = initHelmholtzNinePointCE(systemConfig)

# %% [markdown]
# ## Source initialization

# %%
q       = np.zeros(mesh.nN)
qI      = Utils.closestPoints(mesh, sLoc, gridLoc='N')
q[qI]   = 1

# %% [markdown]
# ## Testing

# %%
# %%time
u       = Ainv * q
# Out:
# CPU times: user 62.5 ms, sys: 2.03 ms, total: 64.6 ms
# Wall time: 17.1 ms

# %%
amax    = abs(u).max()

ax1 = plt.subplot(1,2,1, aspect=1)
plt.set_cmap(cm.gray_r)
im1 = mesh.plotImage(q, vType='N', ax=ax1)
plt.title('Source location')

ax2 = plt.subplot(1,2,2, aspect=1)
plt.set_cmap(cm.bwr)
im2 = mesh.plotImage(u, vType='N', ax=ax2)
im2[0].set_clim(-amax, amax)
plt.title('Wavefield')

# %%
# %%time
sLoc    = [ 10,100] # x, z
q       = np.zeros(mesh.nN)
qI      = Utils.closestPoints(mesh, sLoc, gridLoc='N')
q[qI]   = 1
u       = Ainv * q
# Out:
# CPU times: user 58.9 ms, sys: 3.29 ms, total: 62.1 ms
# Wall time: 17.7 ms

# %%
amax    = abs(u).max()

ax1 = plt.subplot(1,2,1, aspect=1)
plt.set_cmap(cm.gray_r)
im1 = mesh.plotImage(q, vType='N', ax=ax1)
plt.title('Source location')

ax2 = plt.subplot(1,2,2, aspect=1)
plt.set_cmap(cm.bwr)
im2 = mesh.plotImage(u, vType='N', ax=ax2)
im2[0].set_clim(-amax, amax)
plt.title('Wavefield')
