# %% [markdown]
# # Basic Helmholtz solver
#
# Brendan Smithyman |
# September 2014

# %%
import numpy as np
import SimPEG
from SimPEG import Utils
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Configuration
cellSize    = 1         # m
freq        = 1e2       # Hz        (should this be multiplied by 2*pi?)
velocity    = 2000      # m/s
nx          = 100       # count
nz          = 200       # count
sLoc        = [ 10,190] # x, z

# %%
# Mesh initialization
hx      = np.ones(nx) * cellSize
hz      = np.ones(nz) * cellSize
mesh    = SimPEG.Mesh.TensorMesh([hx, hz], '00')
omega   = 2 * np.pi * freq
c       = np.ones(mesh.nC) * velocity               #   (nx * nz)   by 1
L       = mesh.nodalLaplacian                       # (nx+1 * nz+1) by (nx+1 * nz+1)
mAve    = mesh.aveN2CC                              #   (nx * nz)   by (nx+1 * nz+1)
k2      = Utils.sdiag(mAve.T * (omega**2 / c**2))
A       = L + k2
# Out:
# Warning: Laplacian has not been tested rigorously.

# %%
# Source initialization
q       = np.zeros(mesh.nN)
qI      = Utils.closestPoints(mesh, sLoc, gridLoc='N')
q[qI]   = 1

# %%
# %%time
Ainv    = SimPEG.SolverLU(A)
u       = Ainv * q
# Out:
# CPU times: user 363 ms, sys: 12.2 ms, total: 376 ms
# Wall time: 123 ms

# %%
ax = plt.axes(aspect=1)
plt.set_cmap(cm.gray_r)
mesh.plotImage(q, vType='N', ax=ax)
# Out:
# (<matplotlib.collections.QuadMesh at 0x104d3e090>,)

# %%
ax = plt.axes(aspect=1)
plt.set_cmap(cm.bwr)
mesh.plotImage(u, vType='N', ax=ax)
# Out:
# (<matplotlib.collections.QuadMesh at 0x104d4ca90>,)
