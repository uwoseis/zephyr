# %%
import numpy as np
from zephyr.backend import SimpleSource, MiniZephyr25D, AnalyticalHelmholtz

# %%
systemConfig = {
    'dx':       1.,     # m
    'dz':       1.,     # m
    'c':        2500.,  # m/s
    'rho':      1.,     # kg/m^3
    'nx':       100,    # count
    'nz':       200,    # count
    'freq':     2e2,  # Hz
    'nky':      80,
}

# %%
sp = MiniZephyr25D(systemConfig)
ss = SimpleSource(systemConfig)

# %%
q = ss(np.array([[25,25]]))
u = sp*q

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
clip = 1e-2
imshow(u.reshape((200,100)).real, cmap=cm.bwr, vmin=-clip, vmax=clip)
